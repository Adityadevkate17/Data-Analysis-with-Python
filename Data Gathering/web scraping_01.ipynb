# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage = requests.get("https://www.ambitionbox.com/list-of-companies?page=1",headers=headers).text

# %%
# !pip install lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %% [markdown]
# #### Extract all h1 tags from webpage

# %%
soup.find_all('h1')
# Out:
# [<h1 class="companyListing__title">List of companies in India</h1>]

# %%
soup.find_all('h1')[0]
# Out:
# <h1 class="companyListing__title">List of companies in India</h1>

# %%
soup.find_all('h1')[0].text
# Out:
# 'List of companies in India'

# %% [markdown]
# #### h2

# %%
soup.find_all('h2')
# Out:
# [<h2 class="companyCardWrapper__companyName" title="TCS">
#  									TCS
#  								</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Accenture">
#  									Accenture
#  								</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Wipro">
#  									Wipro
#  								</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Cognizant">
#  									Cognizant
#  								</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Capgemini">
#  									Capgemini
#  								</h2>,
#  <h2 class="companyCardWrapper__companyName" title="HDFC Bank">
#  									HDFC Bank
#  								</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Infosys">
#  									Infosys
#  								</h2>,
#  <h2 class="companyCardWrapper__companyName" title="HCLTech">
#  									HCLTech
#  								</h2>,
#  <h2 class="companyCardWrapper__companyName" title="ICICI Bank">
#  									ICICI Bank
#  								</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Tech Mahindra">
# ...

# %%
len(soup.find_all('h2'))
# Out:
# 20

# %%
soup.find_all('h2')[0].text
# Out:
# '\n\t\t\t\t\t\t\t\t\tTCS\n\t\t\t\t\t\t\t\t'

# %%
for i in soup.find_all('h2')[1:-3]:
    print(i.text.strip())
# Out:
# Accenture
# Wipro
# Cognizant
# Capgemini
# HDFC Bank
# Infosys
# HCLTech
# ICICI Bank
# Tech Mahindra
# Genpact
# TP
# Axis Bank
# Jio
# Concentrix Corporation
# Amazon
# Reliance Retail

# %% [markdown]
# #### Extract rating of companies

# %%
len(soup.find_all('div', class_='rating_text rating_text--md'))
# Out:
# 20

# %%
for i in soup.find_all('div', class_='rating_text rating_text--md'):
    print(i.text.strip())
# Out:
# 3.2
# 3.7
# 3.6
# 3.7
# 3.6
# 3.8
# 3.5
# 3.4
# 4.0
# 3.3
# 3.6
# 3.8
# 3.6
# 4.4
# 3.5
# 3.9
# 3.9
# 4.5
# 3.6
# 3.9

# %% [markdown]
# #### Number of reviews

# %%
len(soup.find_all('span',Class="companyCardWrapper_ActionTitle"))`
# Out:
#   Cell In[14], line 1
#     len(soup.find_all('span',Class="companyCardWrapper_ActionTitle"))`
#                                                                      ^
# SyntaxError: invalid syntax

# %%
len(soup.find_all('span', class_='companyCardWrapper__companyRatingCount'))

# %% [markdown]
# ###### correct way but it is confusing
